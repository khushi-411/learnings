# %% [markdown]
# ### Ref: [zero_to_thunder](https://github.com/Lightning-AI/lightning-thunder/blob/main/notebooks/zero_to_thunder.ipynb)

# %%
import torch, thunder
# Out:
# /home/khushi/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/cuda/__init__.py:141: UserWarning: CUDA initialization: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %% [markdown]
# ### Compiling a first module with Thunder

# %%
class LLaMAMLP(torch.nn.Module):

    def __init__(self, n_embd, intermediate_size) -> None:
        super().__init__()
        self.fc_1 = torch.nn.Linear(n_embd, intermediate_size, bias=False)
        self.fc_2 = torch.nn.Linear(n_embd, intermediate_size, bias=False)
        self.proj = torch.nn.Linear(intermediate_size, n_embd, bias=False)

    def forward(self, x: torch.Tensor) -> torch.Tensor:
        x_fc_1 = self.fc_1(x)
        x_fc_2 = self.fc_2(x)
        x = torch.nn.functional.silu(x_fc_1) * x_fc_2
        return self.proj(x)

with torch.device("cuda"):
    m = LLaMAMLP(4096, 11008)

for p in m.parameters():
    p.requires_grad_(False)

print(m)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 16
#      13         return self.proj(x)
#      15 with torch.device("cuda"):
# ---> 16     m = LLaMAMLP(4096, 11008)
#      18 for p in m.parameters():
#      19     p.requires_grad_(False)
#
# Cell In[2], line 5, in LLaMAMLP.__init__(self, n_embd, intermediate_size)
#       3 def __init__(self, n_embd, intermediate_size) -> None:
#       4     super().__init__()
# ----> 5     self.fc_1 = torch.nn.Linear(n_embd, intermediate_size, bias=False)
#       6     self.fc_2 = torch.nn.Linear(n_embd, intermediate_size, bias=False)
#       7     self.proj = torch.nn.Linear(intermediate_size, n_embd, bias=False)
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/nn/modules/linear.py:98, in Linear.__init__(self, in_features, out_features, bias, device, dtype)
#      96 self.in_features = in_features
#      97 self.out_features = out_features
# ---> 98 self.weight = Parameter(torch.empty((out_features, in_features), **factory_kwargs))
#      99 if bias:
#     100     self.bias = Parameter(torch.empty(out_features, **factory_kwargs))
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/utils/_device.py:77, in DeviceContext.__torch_function__(self, func, types, args, kwargs)
#      75 if func in _device_constructors() and kwargs.get('device') is None:
#      76     kwargs['device'] = self.device
# ---> 77 return func(*args, **kwargs)
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/cuda/__init__.py:302, in _lazy_init()
#     300 if "CUDA_MODULE_LOADING" not in os.environ:
#     301     os.environ["CUDA_MODULE_LOADING"] = "LAZY"
# --> 302 torch._C._cuda_init()
#     303 # Some of the queued calls may reentrantly call _lazy_init();
#     304 # we need to just return without initializing in that case.
#     305 # However, we must not let any *other* threads in!
#     306 _tls.is_initializing = True
#
# RuntimeError: CUDA unknown error - this may be due to an incorrectly set up environment, e.g. changing env variable CUDA_VISIBLE_DEVICES after program start. Setting the available devices to be zero.

# %%
thunder_model = thunder.jit(m)

# %%
thunder_model

# %%
x = torch.randn(2, 2048, 4096, device="cuda")
print('deviation:', (thunder_model(x) - m(x)).abs().max().item())

# %%
# %timeit thunder_model(x); torch.cuda.synchronize()
# %timeit m(x); torch.cuda.synchronize()

# %%
thunder.last_traces(thunder_model)[-1]

# %% [markdown]
# ### Compiling a more complex model

# %%
from litgpt import GPT
from thunder.tests.litgpt_model import Config
cfg = Config.from_name('Llama-2-7b-hf')
cfg.n_layer = 16
torch.set_default_dtype(torch.bfloat16)

with torch.device('cuda'):
    m = GPT(cfg)
m
# Out:
# GPT(
#   (lm_head): Linear(in_features=4096, out_features=32000, bias=False)
#   (transformer): ModuleDict(
#     (wte): Embedding(32000, 4096)
#     (h): ModuleList(
#       (0-15): 16 x Block(
#         (norm_1): RMSNorm()
#         (attn): CausalSelfAttention(
#           (attn): Linear(in_features=4096, out_features=12288, bias=False)
#           (proj): Linear(in_features=4096, out_features=4096, bias=False)
#         )
#         (norm_2): RMSNorm()
#         (mlp): LLaMAMLP(
#           (fc_1): Linear(in_features=4096, out_features=11008, bias=False)
#           (fc_2): Linear(in_features=4096, out_features=11008, bias=False)
#           (proj): Linear(in_features=11008, out_features=4096, bias=False)
#         )
#       )
#     )
#     (ln_f): RMSNorm()
#   )
# )

# %%
thunder_model = thunder.jit(m)

inp = torch.randint(1, m.config.vocab_size, (1, 512), device='cuda')

actual = thunder_model(inp)
expected = m(inp)

print("deviation:", (actual - expected).abs().max().item())
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[11], line 5
#       1 thunder_model = thunder.jit(m)
#       3 inp = torch.randint(1, m.config.vocab_size, (1, 512), device='cuda')
# ----> 5 actual = thunder_model(inp)
#       6 expected = m(inp)
#       8 print("deviation:", (actual - expected).abs().max().item())
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/nn/modules/module.py:1511, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1509     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510 else:
# -> 1511     return self._call_impl(*args, **kwargs)
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/nn/modules/module.py:1520, in Module._call_impl(self, *args, **kwargs)
#    1515 # If we don't have any hooks, we want to skip the rest of the logic in
#    1516 # this function, and just call forward.
#    1517 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1518         or _global_backward_pre_hooks or _global_backward_hooks
#    1519         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520     return forward_call(*args, **kwargs)
#    1522 try:
#    1523     result = None
#
# File ~/Documents/lightning-thunder/thunder/__init__.py:201, in ThunderModule.forward(self, *args, **kwargs)
#     200 def forward(self, *args, **kwargs):
# --> 201     res = self._forward_fn(*args, **kwargs)
#     202     return res
#
# File ~/Documents/lightning-thunder/thunder/__init__.py:655, in jit.<locals>.fn_(*args, **kwargs)
#     652 cache_entry, inps, pro_to_epi = get_computation_and_inputs(*args, **kwargs)
#     653 cs.last_trace_host_execution_start = time.time_ns()
# --> 655 result = cache_entry.computation_fn(*inps)
#     657 if cache_entry.backward_fn:
#     658     # Run the compiled forward function
#     659     data_for_autograd, (saved_tensors, saved_other) = result
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/utils/_contextlib.py:115, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     112 @functools.wraps(func)
#     113 def decorate_context(*args, **kwargs):
#     114     with ctx_factory():
# --> 115         return func(*args, **kwargs)
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/contextlib.py:79, in ContextDecorator.__call__.<locals>.inner(*args, **kwds)
#      76 @wraps(func)
#      77 def inner(*args, **kwds):
#      78     with self._recreate_cm():
# ---> 79         return func(*args, **kwds)
#
# File thunder.augmented_forward_fn_12:131, in augmented_forward_fn(idx, tos1, t_sin, t_transformer_h_0_attn_attn_weight, t_transformer_h_1_attn_attn_weight, t_transformer_h_2_attn_attn_weight, t_transformer_h_3_attn_attn_weight, t_transformer_h_4_attn_attn_weight, t_transformer_h_5_attn_attn_weight, t_transformer_h_6_attn_attn_weight, t_transformer_h_7_attn_attn_weight, t_transformer_h_8_attn_attn_weight, t_transformer_h_9_attn_attn_weight, t_transformer_h_10_attn_attn_weight, t_transformer_h_11_attn_attn_weight, t_transformer_h_12_attn_attn_weight, t_transformer_h_13_attn_attn_weight, t_transformer_h_14_attn_attn_weight, t_transformer_h_15_attn_attn_weight, t_transformer_h_0_mlp_fc_1_weight, t_transformer_h_1_mlp_fc_1_weight, t_transformer_h_2_mlp_fc_1_weight, t_transformer_h_3_mlp_fc_1_weight, t_transformer_h_4_mlp_fc_1_weight, t_transformer_h_5_mlp_fc_1_weight, t_transformer_h_6_mlp_fc_1_weight, t_transformer_h_7_mlp_fc_1_weight, t_transformer_h_8_mlp_fc_1_weight, t_transformer_h_9_mlp_fc_1_weight, t_transformer_h_10_mlp_fc_1_weight, t_transformer_h_11_mlp_fc_1_weight, t_transformer_h_12_mlp_fc_1_weight, t_transformer_h_13_mlp_fc_1_weight, t_transformer_h_14_mlp_fc_1_weight, t_transformer_h_15_mlp_fc_1_weight, t_transformer_h_0_mlp_fc_2_weight, t_transformer_h_1_mlp_fc_2_weight, t_transformer_h_2_mlp_fc_2_weight, t_transformer_h_3_mlp_fc_2_weight, t_transformer_h_4_mlp_fc_2_weight, t_transformer_h_5_mlp_fc_2_weight, t_transformer_h_6_mlp_fc_2_weight, t_transformer_h_7_mlp_fc_2_weight, t_transformer_h_8_mlp_fc_2_weight, t_transformer_h_9_mlp_fc_2_weight, t_transformer_h_10_mlp_fc_2_weight, t_transformer_h_11_mlp_fc_2_weight, t_transformer_h_12_mlp_fc_2_weight, t_transformer_h_13_mlp_fc_2_weight, t_transformer_h_14_mlp_fc_2_weight, t_transformer_h_15_mlp_fc_2_weight, t_lm_head_weight, t_transformer_ln_f_weight, t_transformer_h_0_norm_1_weight, t_transformer_h_10_norm_1_weight, t_transformer_h_11_norm_1_weight, t_transformer_h_12_norm_1_weight, t_transformer_h_13_norm_1_weight, t_transformer_h_14_norm_1_weight, t_transformer_h_15_norm_1_weight, t_transformer_h_1_norm_1_weight, t_transformer_h_2_norm_1_weight, t_transformer_h_3_norm_1_weight, t_transformer_h_4_norm_1_weight, t_transformer_h_5_norm_1_weight, t_transformer_h_6_norm_1_weight, t_transformer_h_7_norm_1_weight, t_transformer_h_8_norm_1_weight, t_transformer_h_9_norm_1_weight, t_transformer_h_0_norm_2_weight, t_transformer_h_1_norm_2_weight, t_transformer_h_2_norm_2_weight, t_transformer_h_3_norm_2_weight, t_transformer_h_4_norm_2_weight, t_transformer_h_5_norm_2_weight, t_transformer_h_6_norm_2_weight, t_transformer_h_7_norm_2_weight, t_transformer_h_8_norm_2_weight, t_transformer_h_9_norm_2_weight, t_transformer_h_10_norm_2_weight, t_transformer_h_11_norm_2_weight, t_transformer_h_12_norm_2_weight, t_transformer_h_13_norm_2_weight, t_transformer_h_14_norm_2_weight, t_transformer_h_15_norm_2_weight, t_transformer_h_0_attn_proj_weight, t_transformer_h_0_mlp_proj_weight, t_transformer_h_1_attn_proj_weight, t_transformer_h_1_mlp_proj_weight, t_transformer_h_2_attn_proj_weight, t_transformer_h_2_mlp_proj_weight, t_transformer_h_3_attn_proj_weight, t_transformer_h_3_mlp_proj_weight, t_transformer_h_4_attn_proj_weight, t_transformer_h_4_mlp_proj_weight, t_transformer_h_5_attn_proj_weight, t_transformer_h_5_mlp_proj_weight, t_transformer_h_6_attn_proj_weight, t_transformer_h_6_mlp_proj_weight, t_transformer_h_7_attn_proj_weight, t_transformer_h_7_mlp_proj_weight, t_transformer_h_8_attn_proj_weight, t_transformer_h_8_mlp_proj_weight, t_transformer_h_9_attn_proj_weight, t_transformer_h_9_mlp_proj_weight, t_transformer_h_10_attn_proj_weight, t_transformer_h_10_mlp_proj_weight, t_transformer_h_11_attn_proj_weight, t_transformer_h_11_mlp_proj_weight, t_transformer_h_12_attn_proj_weight, t_transformer_h_12_mlp_proj_weight, t_transformer_h_13_attn_proj_weight, t_transformer_h_13_mlp_proj_weight, t_transformer_h_14_attn_proj_weight, t_transformer_h_14_mlp_proj_weight, t_transformer_ ...
#     129 t0 = torch_slice_prim_impl(tos1, [0, 0], [512, 128], [1, 1])  # t0: "cuda:0 f32[512, 128]"
#     130 t1 = torch_slice_prim_impl(t_sin, [0, 0], [512, 128], [1, 1])  # t1: "cuda:0 f32[512, 128]"
# --> 131 t4 = torch.nn.functional.embedding(idx, t_transformer_wte_weight, None, None, 2.0, False, False)  # t4: "cuda:0 bf16[1, 512, 4096]"
#     132 t5 = Tensor.to(t4, torch.float32, copy=True)  # t5: "cuda:0 f32[1, 512, 4096]"
#     133 t6 = torch.mul(t5, t5)  # t6: "cuda:0 f32[1, 512, 4096]"
#
# File ~/anaconda3/envs/thunder-dev/lib/python3.10/site-packages/torch/nn/functional.py:2237, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2231     # Note [embedding_renorm set_grad_enabled]
#    2232     # XXX: equivalent to
#    2233     # with torch.no_grad():
#    2234     #   torch.embedding_renorm_
#    2235     # remove once script supports set_grad_enabled
#    2236     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2237 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# RuntimeError: CUDA error: unspecified launch failure
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1.
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
print(actual.grad_fn)
thunder.last_traces(thunder_model)[-1]

# %%
actual

# %%
del actual, expected
import gc
gc.collect();

# %%
# %timeit r = m(inp); torch.autograd.grad(r.sum(), m.parameters()); torch.cuda.synchronize()
# %timeit r = thunder_model(inp); torch.autograd.grad(r.sum(), m.parameters()); torch.cuda.synchronize()

# %%
del m, thunder_model
import gc
gc.collect()
torch.cuda.empty_cache()

# %% [markdown]
# ### Distributed with Thunder

# %%
# %%writefile zero_to_thunder_fsdp_simple_example.py
from thunder.tests.litgpt_model import GPT, Config
import os
import torch, torch.distributed
import thumder, thunder.distributed

# create model
device = 'cpu'
torch.set_default_dtype(torch.bfloat16)
cfg = Config.from_model('Llama-2-7b-hf')
cfg.n_layer = 8
model = GPT(cfg)

# setup for distributed
torch.distributed.init_process_group(backend='nccl')
rank = int(os.environ["LOCAL_RANK"])

device = f"cuda:{rank}"
x = torch.randint(1, model.config.vocab_size, (1, 1024), device=device)

model = thunder.jit(thunder.distributed.fsdp(model))
print(f"rank {rank} computing")

for i in range(10):
    res = model(x)
    res.sum().backward()

# %%
# !torchrun --nproc_per_node=2 zero_to_thunder_fsdp_simple_example.py

# %% [markdown]
# ### Extending Thunder

# %%
my_ex = thunder.extend.OperatorExecutor('my_ex', version='0.0.1')
thunder.extend.register_executor(my_ex)

# %%
import litgpt

def apply_rope_copy(x: torch.Tensor, cos: torch.Tensor, sin: torch.Tensor) -> torch.Tensor:
    head_size = x.size(-1)
    x1 = x[..., : head_size // 2]
    x2 = x[..., head_size // 2 :]
    rotated = torch.cat((-x2, x1), dim=-1)
    roped = (x * cos) + (rotated * sin)
    return roped.to(dtype=x.dtype)

# %% [markdown]
# ### Registering Operators

# %%
import torch, thunder
from thunder.tests.litgpt_model import GPT
from thunder import TensorProxy

def apply_rope_impl(x: torch.Tensor, cos: torch.Tensor, sin: torch.Tensor) -> torch.Tensor:
    return litgpt.model.apply_rope(x, cos, sin)

def apply_rope_meta(a: TensorProxy, cos: TensorProxy, sin: TensorProxy) -> TensorProxy:
    return TensorProxy(like=x)

apply_rope = my_ex.registor_operator('apply_rope', like=apply_rope_meta, fn=apply_rope_impl,
                                     replaces=litgpt.model.apply_rope)

# %% [markdown]
# ### Testing our new operator

# %%
with torch.device("cuda"):
    m = GPT.from_name('llama2-like')
    Q = torch.randn(2, 128, 4096, 16)

def test_apply_rope(x, m):
    return litgpt.model.apply_rope(x, m.cos, m.sin)

thunder_apply_rope = thunder.jit(test_apply_rope, executors=(my_ex,) + thunder.get_default_executors())

expected = test_apply_rope(Q, m)
actual = thunder_apply_rope(Q, m)
print("deviation:", (expected - actual).abs().max().item())

thunder.last_traces(thunder_apply_rope)[-1]

# %% [markdown]
# ### Optimized Kernels

# %%
import triton
import triton.language as tl
import torch

MAX_FUSED_SIZE = 65536
next_power_of_2 = triton.next_power_of_2

def calculate_settings(n):
    BLOCK_SIZE = next_power_of_2(n)
    if BLOCK_SIZE > MAX_FUSED_SIZE:
        raise RuntimeError(f"Cannot launch Triton kernel since n = {n} exceeds "\
                           f"the maximum CUDA blocksize = {MAX_FUSED_SIZE}.")
    num_wraps = 4
    if BLOCK_SIZE >= 32768:
        num_wraps = 32
    elif BLOCK_SIZE >= 8182:
        num_wraps = 16
    elif BLOCK_SIZE >= 2048:
        num_wraps = 8
    return BLOCK_SIZE, num_wraps

@triton.heuristics({"BACKWARD_PASS": lambda args: args["BACKWARD_PASS"],})
@triton.jit
def _rope_embedding(
    Q,     Q_row_stride,
    cos, cos_row_stride,
    sin, sin_row_stride,
    seqlen, head_dim, group_size, n_heads,
    BACKWARD_PASS: tl.constexpr,
    BLOCK_SIZE : tl.constexpr,
):
    """
        Calculates the RoPE Embedding quickly
        RoPE is Q * cos + rotate_half(Q) * sin
        See our blog post for more info
    """
    row_position  = tl.program_id(0)
    group_head_position = tl.program_id(1)
    col_offsets  = tl.arange(0, BLOCK_SIZE)
    half_head_dim = head_dim // 2
    mask = col_offsets < half_head_dim

    sin1 = tl.load(sin + (row_position % seqlen)*sin_row_stride + \
                   half_head_dim*0 + col_offsets, mask = mask, other = 0)
    cos1 = tl.load(cos + (row_position % seqlen)*cos_row_stride + \
                   half_head_dim*0 + col_offsets, mask = mask, other = 0)

    if BACKWARD_PASS:
        # See our blog post for more info.
        sin1 = -sin1
    pass

    head_start = group_head_position * group_size
    head_end = min((head_start + group_size), n_heads)

    for i in range(head_start, head_end):
        offs_q1 = row_position * Q_row_stride + i * head_dim + col_offsets
        offs_q2 = row_position * Q_row_stride + i * head_dim + col_offsets + half_head_dim

        # For Gemma - sometimes RoPE must be done in float32 and not bfloat16
        Q1   = tl.load(Q + offs_q1, mask = mask, other = 0).to(sin1.dtype)
        Q2   = tl.load(Q + offs_q2, mask = mask, other = 0).to(sin1.dtype)

        tl.store(Q + offs_q1, Q1*cos1 - Q2*sin1, mask = mask)
        tl.store(Q + offs_q2, Q2*cos1 + Q1*sin1, mask = mask)
    pass
pass

def fast_rope_embedding_forward(Q, cos, sin):
    Q = Q.transpose(1, 2).clone()
    cos, sin = cos.squeeze(), sin.squeeze()
    batch, seq_len, n_heads, head_dim = Q.shape
    Q = Q.reshape(batch*seq_len, n_heads*head_dim)
    n_rows, n_cols = Q.shape
    assert(seq_len <= cos.shape[0])

    # [TODO] Changing blocksize to head_dim//2 seems to have
    # some concurrency / un-deterministic issues.
    BLOCK_SIZE, num_warps = calculate_settings(head_dim//2) # (head_dim//2)
    group_size = 4 # 4 or 8, too large group_size can hurt performance.
    n_groups = triton.cdiv(n_heads, group_size)

    grid = (n_rows, n_groups, )
    _rope_embedding[grid](
          Q,   Q.stride(0),
        cos, cos.stride(0),
        sin, sin.stride(0),
        seq_len, head_dim, group_size, n_heads,
        BACKWARD_PASS = False,
        BLOCK_SIZE = BLOCK_SIZE,
        num_warps  = num_warps,
    )
    Q = Q.view(batch, seq_len, n_heads, head_dim).transpose(1, 2)
    return Q, (BLOCK_SIZE, num_warps) 

def fast_rope_embedding_backward(BLOCK_SIZE, num_warps, cos, sin, dY):
    dY = dY.transpose(1, 2)
    batch, seq_len, n_heads, head_dim = dY.shape
    dY = dY.reshape(batch*seq_len, n_heads*head_dim)
    # Must be reshape not view
    n_rows, n_cols = dY.shape

    group_size = 4 # 4 or 8, too large group_size can hurt performance.
    n_groups = triton.cdiv(n_heads, group_size)

    grid = (n_rows, n_groups, )
    _rope_embedding[grid](
        dY,  dY .stride(0),
        cos, cos.stride(0),
        sin, sin.stride(0),
        seq_len, head_dim, group_size, n_heads,
        BACKWARD_PASS = True,
        BLOCK_SIZE = BLOCK_SIZE,
        num_warps  = num_warps,
    )
    dY = dY.view(batch, seq_len, n_heads, head_dim)
    dY = dY.transpose(1, 2)    
    return dY
# Out:
#   Cell In[12], line 10
#     if BLOCK_SIZE > MAX_FUSED_SIZE:
#                                    ^
# IndentationError: expected an indented block after 'if' statement on line 10

# %%
def fast_rope_embedding_forward_meta(Q, cos, sin):
    batch, n_heads, seq_len, head_dim = Q.shape
    n_rows, n_cols = batch*seq_len, n_heads*head_dim 
    assert(seq_len <= cos.shape[0])

    BLOCK_SIZE, num_warps = calculate_settings(head_dim//2)
    return TensorProxy(like=Q), (BLOCK_SIZE, num_warps) 

def fast_rope_embedding_backward_meta(BLOCK_SIZE, num_warps, cos, sin, dY):
    return TensorProxy(like=dY)

# %% [markdown]
# ### Implementations for operators

# %%
def apply_rope_to_unsloth(x: TensorProxy, cos: TensorProxy, sin: TensorProxy) -> TensorProxy:
    assert len(x.shape) == 4
    res, *_ = unsloth_apply_rope_forward(x, cos, sin)
    return res

def apply_rope_to_unsloth_checker(x: TensorProxy, cos: TensorProxy, sin: TensorProxy) -> bool:
    if len(x.shape) != 4:
        return False
    return (x.device.devicetype == thunder.devices.DeviceType.CUDA and
            cos.device.devicetype == thunder.devices.DeviceType.CUDA and
           cos.device.devicetype == thunder.devices.DeviceType.CUDA)

my_ex.register_implementation(apply_rope,
                              checker=apply_rope_to_unsloth_checker,
                              execution_transform=apply_rope_to_unsloth)

# %%
thunder_apply_rope = thunder.jit(test_apply_rope, executors=(my_ex,) + thunder.get_default_executors())    

expected = test_apply_rope(Q, m)
actual = thunder_apply_rope(Q, m)
print("deviation:", (expected - actual).abs().max().item())

thunder.last_traces(thunder_apply_rope)[-1]

# %%
torch.set_default_dtype(torch.float32)
with torch.device('cuda'):
    m = GPT(Config.from_name('llama2-like'))

for p in m.parameters():
    p.requires_grad_(False)

thunder_model = thunder.jit(m, executors=(my_ex,) + thunder.get_default_executors())

inp = torch.randint(1, m.config.vocab_size, (1, 128), device="cuda")
actual = thunder_model(inp)
expected = m(inp)

print("deviation:", (actual - expected).abs().max().item())

# %%
[s for s in str(thunder.last_traces(thunder_model)[-1]).split('\n') if 'apply_rope' in s]
